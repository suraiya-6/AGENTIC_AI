# %% [markdown]
# Pandas is a Python library used to store, organize, clean, and analyze data in table format

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# A Pandas Series is a one-dimensional labeled array used to store a single column of data in pandas.

# %%
#from list
ser=pd.Series([1,2,3,4,5])
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#custom index
ser=pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
print(ser)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
student={
    "name":"sireesha",
    "branch":"aiml"
}
se=pd.Series(student)
print(se)
# Out:
# name      sireesha
# branch        aiml
# dtype: object

# %%
A=pd.Series([5,6,9,8,7])

# %%
A+2
# Out:
# 0     7
# 1     8
# 2    11
# 3    10
# 4     9
# dtype: int64

# %%
A*3
# Out:
# 0    15
# 1    18
# 2    27
# 3    24
# 4    21
# dtype: int64

# %%
A.mean()
# Out:
# np.float64(7.0)

# %%
A.sum()
# Out:
# np.int64(35)

# %%
A.max()
# Out:
# 9

# %%
A.describe()
# Out:
# count    5.000000
# mean     7.000000
# std      1.581139
# min      5.000000
# 25%      6.000000
# 50%      7.000000
# 75%      8.000000
# max      9.000000
# dtype: float64

# %%
# Boolean indexing
A[A > 3]
# Out:
# 0    5
# 1    6
# 2    9
# 3    8
# 4    7
# dtype: int64

# %%
# Vectorized string operations
names = pd.Series(['Siree', 'suma', 'renu'])
names.str.lower()
names.str.len()
names.str.startswith('S')
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# A DataFrame is a two-dimensional table in pandas used to store data in rows and columns.

# %%
 # From dictionary
student = {
    'Name':   ['siree', 'suma', 'renu', 'iqra'],
    'Age':    [23, 25, 22, 28],
    'Score':  [88, 75, 92, 81],
    'Grade':  ['A', 'B', 'A', 'A']
}
a = pd.DataFrame(student)
print(a)
# Out:
#     Name  Age  Score Grade
# 0  siree   23     88     A
# 1   suma   25     75     B
# 2   renu   22     92     A
# 3   iqra   28     81     A

# %%
student = [{'name': 'siree', 'age': 23}, {'names': 'devika', 'age': 18}]
b = pd.DataFrame(student)
print(b)
# Out:
#     name  age   names
# 0  siree   23     NaN
# 1    NaN   18  devika

# %%
# From NumPy array
arr = np.random.rand(4, 4)
c = pd.DataFrame(arr, columns=['A','B','C','D'], index=['x','y','z','u'])
print(c)
# Out:
#           A         B         C         D
# x  0.067627  0.895444  0.810433  0.938649
# y  0.395881  0.088152  0.566516  0.862980
# z  0.677890  0.941273  0.834002  0.710679
# u  0.085897  0.982980  0.831974  0.012228

# %%
# Exporing Data Frame

data = {
    'Name':   ['siree', 'renu', 'suma', 'iqra'],
    'Age':    [23, 25, 22, 28],
    'Score':  [95, 82, 92, 81],
    'Grade':  ['A', 'B', 'A', 'A']
}
d = pd.DataFrame(data)

# %%
print(d.head(3))
print(d.tail(3))
print(d.shape)
print(d.info())
print(d.describe())
print(d.columns)
print(d.index)
print(d.dtypes)
print(d.nunique())
print(d.isnull().sum())
# Out:
#     Name  Age  Score Grade
# 0  siree   23     95     A
# 1   renu   25     82     B
# 2   suma   22     92     A
#    Name  Age  Score Grade
# 1  renu   25     82     B
# 2  suma   22     92     A
# 3  iqra   28     81     A
# (4, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Score   4 non-null      int64
#  3   Grade   4 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 260.0+ bytes
# None
#              Age      Score
# count   4.000000   4.000000
# mean   24.500000  87.500000
# std     2.645751   7.047458
# min    22.000000  81.000000
# 25%    22.750000  81.750000
# 50%    24.000000  87.000000
# 75%    25.750000  92.750000
# max    28.000000  95.000000
# Index(['Name', 'Age', 'Score', 'Grade'], dtype='object')
# RangeIndex(start=0, stop=4, step=1)
# ...

# %%
d['Name']
# Out:
# 0    siree
# 1     renu
# 2     suma
# 3     iqra
# Name: Name, dtype: object

# %%
d.Name
# Out:
# 0    siree
# 1     renu
# 2     suma
# 3     iqra
# Name: Name, dtype: object

# %%
d[['Name', 'Score']]
# Out:
#     Name  Score
# 0  siree     95
# 1   renu     82
# 2   suma     92
# 3   iqra     81

# %%
d.loc[0]
# Out:
# Name     siree
# Age         23
# Score       95
# Grade        A
# Name: 0, dtype: object

# %%
d.loc[0:2]
# Out:
#     Name  Age  Score Grade
# 0  siree   23     95     A
# 1   renu   25     82     B
# 2   suma   22     92     A

# %%
d.loc[0:2, 'Name':'Score']
# Out:
#     Name  Age  Score
# 0  siree   23     95
# 1   renu   25     82
# 2   suma   22     92

# %%
print(d.iloc[0])
print(d.iloc[0:2])
print(d.iloc[0:2 , 0:2])
print(d.iloc[-1])
# Out:
# Name     siree
# Age         23
# Score       95
# Grade        A
# Name: 0, dtype: object
#     Name  Age  Score Grade
# 0  siree   23     95     A
# 1   renu   25     82     B
#     Name  Age
# 0  siree   23
# 1   renu   25
# Name     iqra
# Age        28
# Score      81
# Grade       A
# Name: 3, dtype: object

# %%
d.loc[0, 'Name']
# Out:
# 'siree'

# %%
d.iloc[0, 0]
# Out:
# 'siree'

# %%
d[(d['Score'] > 80)]
# Out:
#     Name  Age  Score Grade
# 0  siree   23     95     A
# 1   renu   25     82     B
# 2   suma   22     92     A
# 3   iqra   28     81     A

# %%
# Multiple conditions: use & (and) | (or) ~ (not)
d[(d['Score'] > 80) & (d['Grade'] == 'A')]
d[(d['Age'] < 24) | (d['Score'] > 90)]
# Out:
#     Name  Age  Score Grade
# 0  siree   23     95     A
# 2   suma   22     92     A

# %%
d.query('Score > 80 and Age < 25')
d.query('Grade == "A"')
# Out:
#     Name  Age  Score Grade
# 0  siree   23     95     A
# 2   suma   22     92     A
# 3   iqra   28     81     A

# %%
d[d['Name'].isin(['siree', 'devika'])]
# Out:
#     Name  Age  Score Grade
# 0  siree   23     95     A

# %%
d['grade']=d['Score']>=80

# %%
d['example']=["a","b","c","d"]

# %%
d['percentage'] = d['Score'] * 0.1
d['Pass'] = d['Score'] >= 80
print(d)
# Out:
#     Name  Age  Score Grade  grade example  percentage  Pass
# 0  siree   23     95     A   True       a         9.5  True
# 1   renu   25     82     B   True       b         8.2  True
# 2   suma   22     92     A   True       c         9.2  True
# 3   iqra   28     81     A   True       d         8.1  True

# %%
print(d)
# Out:
#     Name  Age  Score Grade  grade example  percentage  Pass
# 0  siree   23     95     A   True       a         9.5  True
# 1   renu   25     82     B   True       b         8.2  True
# 2   suma   22     92     A   True       c         9.2  True
# 3   iqra   28     81     A   True       d         8.1  True

# %%
d['Score']=d['Score']+5

# %%
def grade(Score):
  if (Score>=90):
    return 'A'
  elif (Score>=60 and Score<80):
      return 'B'
  else:
    return "fail"
print(d)
# Out:
#     Name  Age  Score Grade  grade example  percentage  Pass
# 0  siree   23    100     A   True       a         9.5  True
# 1   renu   25     87     B   True       b         8.2  True
# 2   suma   22     97     A   True       c         9.2  True
# 3   iqra   28     86     A   True       d         8.1  True

# %%
result={
    True:"pass",
    False:"fail"
}
pas={'A':90,'B':80,'D':60}

# %%
d['pass']=d['Grade'].map(pas)
d['result']=d['grade'].map(result)
print(d)
# Out:
#     Name  Age  Score Grade  grade example  percentage  Pass  pass result
# 0  siree   23    100     A   True       a         9.5  True    90   pass
# 1   renu   25     87     B   True       b         8.2  True    80   pass
# 2   suma   22     97     A   True       c         9.2  True    90   pass
# 3   iqra   28     86     A   True       d         8.1  True    90   pass

# %%
d.drop('pass', axis=1, inplace=True)
d.drop(columns=['Pass', 'percentage'], inplace=True)
print(d)
# Out:
#     Name  Age  Score Grade  grade example result
# 0  siree   23    100     A   True       a   pass
# 1   renu   25     87     B   True       b   pass
# 2   suma   22     97     A   True       c   pass
# 3   iqra   28     86     A   True       d   pass

# %%
d.rename(columns={'Score':'marks','Name':'student'}, inplace=True)
print(d)
# Out:
#   student  Age  marks Grade  grade example result
# 0   siree   23    100     A   True       a   pass
# 1    renu   25     87     B   True       b   pass
# 2    suma   22     97     A   True       c   pass
# 3    iqra   28     86     A   True       d   pass

# %%
d.fillna(0)
d['Age'].fillna(d['Age'].mean(), inplace=True)
print(d)
# Out:
#   student  Age  marks Grade  grade example result
# 0   siree   23    100     A   True       a   pass
# 1    renu   25     87     B   True       b   pass
# 2    suma   22     97     A   True       c   pass
# 3    iqra   28     86     A   True       d   pass
# /tmp/ipykernel_2259/873466.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d['Age'].fillna(d['Age'].mean(), inplace=True)

# %%
d.replace('B',np.nan, inplace=True)
print(d)
# Out:
#   student  Age  marks Grade  grade example result
# 0   siree   23    100     A   True       a   pass
# 1    renu   25     87   NaN   True       b   pass
# 2    suma   22     97     A   True       c   pass
# 3    iqra   28     86     A   True       d   pass

# %%
d.sort_values('marks',ascending=True)
# Out:
#   student  Age  marks Grade  grade example result
# 3    iqra   28     86     A   True       d   pass
# 1    renu   25     87   NaN   True       b   pass
# 2    suma   22     97     A   True       c   pass
# 0   siree   23    100     A   True       a   pass

# %%
d.sort_index(ascending=False)
# Out:
#   student  Age  marks Grade  grade example result
# 3    iqra   28     86     A   True       d   pass
# 2    suma   22     97     A   True       c   pass
# 1    renu   25     87   NaN   True       b   pass
# 0   siree   23    100     A   True       a   pass

# %%
d.nlargest(4, 'marks')
d.nsmallest(3, 'Age')
# Out:
#   student  Age  marks Grade  grade example result
# 2    suma   22     97     A   True       c   pass
# 0   siree   23    100     A   True       a   pass
# 1    renu   25     87   NaN   True       b   pass

# %%
data = {
    'Department': ['IT','HR','IT','HR','IT'],
    'Name': ['siree','suma','renu','iqra','devi'],
    'Salary': [70000, 50000, 80000, 55000, 75000],
    'YearsExp': [3, 5, 7, 2, 4]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Department   Name  Salary  YearsExp
# 0         IT  siree   70000         3
# 1         HR   suma   50000         5
# 2         IT   renu   80000         7
# 3         HR   iqra   55000         2
# 4         IT   devi   75000         4

# %%
df.groupby('Department')['Salary'].max()
# Out:
# Department
# HR    55000
# IT    80000
# Name: Salary, dtype: int64

# %%
employees = pd.DataFrame({
    'emp_id': [1, 2, 3, 4],
    'name': ['siree','suma','renu','iqra'],
    'dept_id': [10, 20, 10, 30]
})

departments = pd.DataFrame({
    'dept_id': [10, 20],
    'dept_name': ['Engineering', 'HR']
})

# %%
pd.merge(employees, departments, on='dept_id', how='inner')
# Out:
#    emp_id   name  dept_id    dept_name
# 0       1  siree       10  Engineering
# 1       2   suma       20           HR
# 2       3   renu       10  Engineering

# %%
pd.merge(employees, departments, on='dept_id', how='left')
# Out:
#    emp_id   name  dept_id    dept_name
# 0       1  siree       10  Engineering
# 1       2   suma       20           HR
# 2       3   renu       10  Engineering
# 3       4   iqra       30          NaN
